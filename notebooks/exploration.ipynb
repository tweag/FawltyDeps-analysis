# %%
import json
import os
from pathlib import Path
from typing import List, Dict, Any

# %%
def filter_corrupt_files(paths: List[Path]) -> (List[Dict[str, Any]], List[str]):
    """
    Filter out files that are not valid json files
    """
    data = {}
    corrupt_files = []
    for path in paths:
        try:
            with open(path, "r") as f:
                single_result = json.load(f)
            data[path.name] = single_result
        except json.decoder.JSONDecodeError:
            corrupt_files.append(path.name)
    return data, corrupt_files

# %%
# import Zhinan's data

paths = "../data/zhihan/"

data_z, corrupt_z = filter_corrupt_files([Path(paths) / file for file in os.listdir(paths)])

# %%
corrupt_z
# Out:
# []

# %%
len(data_z)
# Out:
# 1759

# %% [markdown]
# # Dorran's data
#
#
# Represents list of Python projects (or in the Python ecosystem) that were downloaded in 2023
#
# ```sql
# SELECT DISTINCT projects.name, REPLACE(projects.url, 'Source, ', '') as trimmed_url, counts.annual_downloads, meta.keywords
# -- Get source URL(s) for project
# FROM (
#   SELECT name, url
#   FROM `bigquery-public-data.pypi.distribution_metadata`
#   CROSS JOIN UNNEST(project_urls) AS url
#   WHERE url LIKE 'Source, %'
# ) as projects
# -- Add in download count from 2023
# LEFT JOIN (
#   SELECT project, COUNT(project) as annual_downloads
#   FROM `bigquery-public-data.pypi.file_downloads`
#   WHERE TIMESTAMP_TRUNC(timestamp, DAY) >= TIMESTAMP("2023-01-01") AND TIMESTAMP_TRUNC(timestamp, DAY) < TIMESTAMP("2024-01-01")
#   GROUP BY project
# ) AS counts
# ON projects.name = counts.project
# -- Add in keywords from most recent upload
# LEFT JOIN (
#   SELECT DISTINCT name, keywords
#   FROM (
#     SELECT name, keywords, ROW_NUMBER() OVER (PARTITION BY name ORDER BY upload_time DESC) as rn
#     FROM `bigquery-public-data.pypi.distribution_metadata`
#   ) WHERE rn = 1
# ) meta
# ON projects.name = meta.name`

# %%
# Dorran's data  

paths = "../data/dorran/"

data_d, corrupt_d = filter_corrupt_files([Path(paths) / file for file in os.listdir(paths)])

# %%
len(corrupt_d)
# Out:
# 139

# %%
len(data_d)
# Out:
# 911

# %%
# json entries examples

for i,(_,v) in enumerate(data_z.items()):
    print( json.dumps(v, indent=4))
    if i>3:
        break
# Out:
# {
#     "project_name": "SSUsearch",
#     "code_dirs": {
#         "scripts": {
#             "py": 29,
#             "ipynb": 0,
#             "total": 29
#         },
#         "notebooks-pc-linux": {
#             "py": 0,
#             "ipynb": 12,
#             "total": 12
#         },
#         "notebooks": {
#             "py": 0,
#             "ipynb": 12,
#             "total": 12
#         }
#     },
#     "deps_file": [],
#     "imports": [],
#     "fawltydeps_version": "0.13.1"
# }
# {
#     "project_name": "markerGeneProfile",
#     "code_dirs": null,
#     "deps_file": [],
#     "imports": [],
#     "fawltydeps_version": "0.13.1"
# }
# {
#     "project_name": "evangelist",
#     "code_dirs": {
#         "dna_puller": {
#             "py": 4,
#             "ipynb": 0,
#             "total": 4
#         },
#         "gnuplot_generator": {
#             "py": 2,
#             "ipynb": 0,
#             "total": 2
#         }
#     },
#     "deps_file": [
#         {
#             "source_type": "DepsSource",
#             "path": "requirements.txt",
#             "parser_choice": "requirements.txt",
#             "deps_count": 2,
#             "warnings": false
#         }
#     ],
#     "imports": [],
#     "fawltydeps_version": "0.13.1"
# }
# {
#     "project_name": "vt",
#     "code_dirs": {
#         "lib": {
#             "py": 1,
#             "ipynb": 0,
#             "total": 1
#         }
#     },
#     "deps_file": [],
#     "imports": [],
#     "fawltydeps_version": "0.13.1"
# }
# {
#     "project_name": "PyMICE",
#     "code_dirs": {
#         "lib": {
#             "py": 25,
#             "ipynb": 0,
#             "total": 25
#         },
#         "tutorial": {
#             "py": 0,
#             "ipynb": 10,
#             "total": 10
#         },
#         "sphinx": {
#             "py": 1,
#             "ipynb": 0,
#             "total": 1
#         }
#     },
#     "deps_file": [
#         {
#             "source_type": "DepsSource",
#             "path": "setup.py",
#             "parser_choice": "setup.py",
#             "deps_count": 0,
#             "warnings": true
#         },
#         {
#             "source_type": "DepsSource",
#             "path": "requirements.txt",
#             "parser_choice": "requirements.txt",
#             "deps_count": 4,
#             "warnings": false
#         }
#     ],
#     "imports": [],
#     "fawltydeps_version": "0.13.1"
# }

# %%
for i,(_,v) in enumerate(data_d.items()):
    print( json.dumps(v, indent=4))
    if i>3:
        break
# Out:
# {
#     "project_name": "plyara",
#     "code_dirs": {
#         "/": {
#             "py": 9,
#             "ipynb": 0,
#             "total": 9
#         }
#     },
#     "deps_file": [
#         {
#             "source_type": "DepsSource",
#             "path": "/tmp/tmp3say7qnf/checkout/requirements-dev.txt",
#             "parser_choice": "requirements.txt",
#             "deps_count": 5,
#             "warnings": false
#         },
#         {
#             "source_type": "DepsSource",
#             "path": "/tmp/tmp3say7qnf/checkout/setup.cfg",
#             "parser_choice": "setup.cfg",
#             "deps_count": 0,
#             "warnings": false
#         },
#         {
#             "source_type": "DepsSource",
#             "path": "/tmp/tmp3say7qnf/checkout/setup.py",
#             "parser_choice": "setup.py",
#             "deps_count": 1,
#             "warnings": false
#         }
#     ],
#     "imports": [],
#     "fawltydeps_version": "0.13.1"
# }
# {
#     "project_name": "demoji",
#     "code_dirs": {
#         "/": {
#             "py": 6,
#             "ipynb": 0,
#             "total": 6
#         }
#     },
#     "deps_file": [
#         {
#             "source_type": "DepsSource",
#             "path": "/tmp/tmp8nn719nz/checkout/requirements.txt",
#             "parser_choice": "requirements.txt",
#             "deps_count": 0,
#             "warnings": false
#         },
#         {
#             "source_type": "DepsSource",
#             "path": "/tmp/tmp8nn719nz/checkout/setup.py",
#             "parser_choice": "setup.py",
#             "deps_count": 0,
#             "warnings": false
#         },
#         {
#             "source_type": "DepsSource",
#             "path": "/tmp/tmp8nn719nz/checkout/pyproject.toml",
#             "parser_choice": "pyproject.toml",
#             "deps_count": 0,
#             "warnings": false
#         },
#         {
#             "source_type": "DepsSource",
#             "path": "/tmp/tmp8nn719nz/checkout/setup.cfg",
#             "parser_choice": "setup.cfg",
#             "deps_count": 3,
#             "warnings": false
#         }
#     ],
#     "imports": [
#         {
#             "Alternative imports (primary)": {
#                 "name": "ujson",
#                 "source": {
#                     "path": "/tmp/tmp8nn719nz/checkout/demoji/__init__.py",
#                     "lineno": 24
#                 }
#             }
#         }
#     ],
#     "fawltydeps_version": "0.13.1"
# }
# {
#     "project_name": "redislite",
#     "code_dirs": {
#         "/": {
#             "py": 9,
#             "ipynb": 0,
#             "total": 9
#         }
#     },
#     "deps_file": [
#         {
#             "source_type": "DepsSource",
#             "path": "/tmp/tmpyh8kpger/checkout/setup.py",
#             "parser_choice": "setup.py",
#             "deps_count": 0,
#             "warnings": false
#         },
#         {
#             "source_type": "DepsSource",
#             "path": "/tmp/tmpyh8kpger/checkout/pyproject.toml",
#             "parser_choice": "pyproject.toml",
#             "deps_count": 0,
#             "warnings": false
#         },
#         {
#             "source_type": "DepsSource",
#             "path": "/tmp/tmpyh8kpger/checkout/setup.cfg",
#             "parser_choice": "setup.cfg",
#             "deps_count": 3,
#             "warnings": false
#         }
#     ],
#     "imports": [
#         {
#             "Conditional imports": {
#                 "name": "pkg_resources",
#                 "source": {
#                     "path": "/tmp/tmpyh8kpger/checkout/redislite/__init__.py",
#                     "lineno": 65
#                 }
#             }
#         }
#     ],
#     "fawltydeps_version": "0.13.1"
# }
# {
#     "project_name": "mypy-boto3-iam",
#     "code_dirs": {
#         "/": {
#             "py": 129,
#             "ipynb": 0,
#             "total": 129
#         }
#     },
#     "deps_file": [
#         {
#             "source_type": "DepsSource",
#             "path": "/tmp/tmpry_id306/checkout/types_boto3/setup.py",
#             "parser_choice": "setup.py",
#             "deps_count": 0,
#             "warnings": false
#         },
#         {
#             "source_type": "DepsSource",
#             "path": "/tmp/tmpry_id306/checkout/types_botocore/setup.cfg",
#             "parser_choice": "setup.cfg",
#             "deps_count": 1,
#             "warnings": false
#         },
#         {
#             "source_type": "DepsSource",
#             "path": "/tmp/tmpry_id306/checkout/setup.cfg",
#             "parser_choice": "setup.cfg",
#             "deps_count": 0,
#             "warnings": false
#         },
#         {
#             "source_type": "DepsSource",
#             "path": "/tmp/tmpry_id306/checkout/types_botocore/setup.py",
#             "parser_choice": "setup.py",
#             "deps_count": 0,
#             "warnings": false
#         },
#         {
#             "source_type": "DepsSource",
#             "path": "/tmp/tmpry_id306/checkout/requirements.mkdocs.txt",
#             "parser_choice": "requirements.txt",
#             "deps_count": 2,
#             "warnings": false
#         },
#         {
#             "source_type": "DepsSource",
#             "path": "/tmp/tmpry_id306/checkout/types_boto3/setup.cfg",
#             "parser_choice": "setup.cfg",
#             "deps_count": 1,
#             "warnings": false
#         },
#         {
#             "source_type": "DepsSource",
#             "path": "/tmp/tmpry_id306/checkout/pyproject.toml",
#             "parser_choice": "pyproject.toml",
#             "deps_count": 9,
#             "warnings": false
#         }
#     ],
#     "imports": [],
#     "fawltydeps_version": "0.13.1"
# }
# {
#     "project_name": "frozendict",
#     "code_dirs": {
#         "/": {
#             "py": 14,
#             "ipynb": 0,
#             "total": 14
#         }
#     },
#     "deps_file": [
#         {
#             "source_type": "DepsSource",
#             "path": "/tmp/tmpjzasczwr/checkout/setup.py",
#             "parser_choice": "setup.py",
#             "deps_count": 0,
#             "warnings": false
#         },
#         {
#             "source_type": "DepsSource",
#             "path": "/tmp/tmpjzasczwr/checkout/pyproject.toml",
#             "parser_choice": "pyproject.toml",
#             "deps_count": 0,
#             "warnings": false
#         }
#     ],
#     "imports": [],
#     "fawltydeps_version": "0.13.1"
# }

# %% [markdown]
# Change Dorran's query condition on urls to: (url LIKE 'Source, %' OR url LIKE 'Repository, %')
